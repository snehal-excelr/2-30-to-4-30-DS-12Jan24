# %%
# !pip install -U keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
import tensorflow as tf
from tensorflow.keras.layers import Dense
import keras_tuner as kf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('/content/Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.drop(columns = ['RowNumber'	,'CustomerId',	'Surname'], inplace=True)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
df = pd.get_dummies(data = df,columns=['Geography','Gender'])
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0                  1        101348.88       1                 1
# 1                  1        112542.58       0                 0
# 2                  0        113931.57       1                 1
# 3                  0         93826.63       0                 1
# 4                  1         79084.10       0                 0
# ...              ...              ...     ...               ...
# 9995               0         96270.64       0                 1
# 9996               1        101699.77       0                 1
# 9997               1         42085.58       1                 1
# 9998               0         92888.52       1                 0
# 9999               0         38190.78       0                 1
#
#       Geography_Germany  Geography_Spain  Gender_Female  Gender_Male
# 0                     0                0              1            0
# 1                     0                1              1            0
# 2                     0                0              1            0
# 3                     0                0              1            0
# 4                     0                1              1            0
# ...                 ...              ...            ...          ...
# 9995                  0                0              0            1
# 9996                  0                0              0            1
# 9997                  0                0              1            0
# 9998                  1                0              0            1
# 9999                  0                0              1            0
#
# [10000 rows x 14 columns]

# %%
x = df.drop(columns = ['Exited'])
y = df['Exited']

# %%
sc = StandardScaler()

x = sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.20, random_state=1)

# %%
# Before hyperparameter tuning: initially use random parameters only for comparision
ann = Sequential()# random weights are initialized so every time you will get different accuracy and loss

ann.add(Dense(units = 10, activation = 'relu'))# hidden layer
ann.add(Dense(units = 1, activation = 'sigmoid'))# output layer

ann.compile(optimizer = 'adadelta', loss = 'binary_crossentropy', metrics ='accuracy')

ann.fit(xtrain,ytrain,epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.8509 - accuracy: 0.4080
# Epoch 2/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8499 - accuracy: 0.4094
# Epoch 3/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8488 - accuracy: 0.4103
# Epoch 4/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8477 - accuracy: 0.4109
# Epoch 5/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8466 - accuracy: 0.4116
# Epoch 6/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8455 - accuracy: 0.4119
# Epoch 7/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8443 - accuracy: 0.4123
# Epoch 8/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8432 - accuracy: 0.4132
# Epoch 9/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8420 - accuracy: 0.4135
# Epoch 10/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.8408 - accuracy: 0.4140
# Epoch 11/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.8397 - accuracy: 0.4149
# Epoch 12/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.8385 - accuracy: 0.4154
# Epoch 13/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.8373 - accuracy: 0.4159
# Epoch 14/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.8362 - accuracy: 0.4173
# Epoch 15/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8350 - accuracy: 0.4180
# Epoch 16/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8339 - accuracy: 0.4191
# Epoch 17/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8327 - accuracy: 0.4195
# Epoch 18/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8316 - accuracy: 0.4195
# Epoch 19/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8304 - accuracy: 0.4205
# Epoch 20/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8292 - accuracy: 0.4219
# Epoch 21/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8281 - accuracy: 0.4225
# Epoch 22/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8269 - accuracy: 0.4234
# Epoch 23/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8258 - accuracy: 0.4249
# Epoch 24/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8246 - accuracy: 0.4261
# Epoch 25/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8235 - accuracy: 0.4266
# Epoch 26/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8224 - accuracy: 0.4272
# Epoch 27/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8212 - accuracy: 0.4279
# Epoch 28/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8201 - accuracy: 0.4283
# Epoch 29/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8189 - accuracy: 0.4291
# Epoch 30/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8178 - accuracy: 0.4291
# Epoch 31/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8167 - accuracy: 0.4293
# Epoch 32/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8156 - accuracy: 0.4304
# Epoch 33/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8144 - accuracy: 0.4311
# Epoch 34/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8133 - accuracy: 0.4324
# Epoch 35/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8122 - accuracy: 0.4325
# Epoch 36/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8111 - accuracy: 0.4326
# Epoch 37/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8100 - accuracy: 0.4335
# Epoch 38/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8089 - accuracy: 0.4339
# Epoch 39/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.8079 - accuracy: 0.4354
# Epoch 40/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.8068 - accuracy: 0.4359
# Epoch 41/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.8057 - accuracy: 0.4371
# Epoch 42/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.8047 - accuracy: 0.4384
# Epoch 43/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.8036 - accuracy: 0.4387
# Epoch 44/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8025 - accuracy: 0.4396
# Epoch 45/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8015 - accuracy: 0.4403
# Epoch 46/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.8004 - accuracy: 0.4405
# Epoch 47/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7993 - accuracy: 0.4408
# Epoch 48/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7983 - accuracy: 0.4419
# Epoch 49/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7972 - accuracy: 0.4423
# Epoch 50/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7961 - accuracy: 0.4426
# Epoch 51/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7951 - accuracy: 0.4430
# Epoch 52/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7941 - accuracy: 0.4441
# Epoch 53/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7930 - accuracy: 0.4451
# Epoch 54/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7920 - accuracy: 0.4459
# Epoch 55/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7910 - accuracy: 0.4465
# Epoch 56/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7900 - accuracy: 0.4474
# Epoch 57/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7890 - accuracy: 0.4485
# Epoch 58/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7880 - accuracy: 0.4493
# Epoch 59/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7870 - accuracy: 0.4499
# Epoch 60/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7860 - accuracy: 0.4509
# Epoch 61/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7850 - accuracy: 0.4520
# Epoch 62/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7840 - accuracy: 0.4534
# Epoch 63/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7830 - accuracy: 0.4543
# Epoch 64/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7820 - accuracy: 0.4549
# Epoch 65/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7811 - accuracy: 0.4555
# Epoch 66/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7801 - accuracy: 0.4559
# Epoch 67/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7791 - accuracy: 0.4569
# Epoch 68/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.7781 - accuracy: 0.4584
# Epoch 69/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.7772 - accuracy: 0.4586
# Epoch 70/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.7762 - accuracy: 0.4589
# Epoch 71/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7753 - accuracy: 0.4597
# Epoch 72/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7743 - accuracy: 0.4611
# Epoch 73/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7734 - accuracy: 0.4620
# Epoch 74/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7724 - accuracy: 0.4629
# Epoch 75/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7715 - accuracy: 0.4631
# Epoch 76/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7705 - accuracy: 0.4638
# Epoch 77/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7695 - accuracy: 0.4651
# Epoch 78/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7686 - accuracy: 0.4661
# Epoch 79/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7676 - accuracy: 0.4670
# Epoch 80/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7667 - accuracy: 0.4675
# Epoch 81/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7657 - accuracy: 0.4681
# Epoch 82/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7648 - accuracy: 0.4683
# Epoch 83/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7639 - accuracy: 0.4691
# Epoch 84/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7630 - accuracy: 0.4696
# Epoch 85/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7620 - accuracy: 0.4708
# Epoch 86/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7611 - accuracy: 0.4714
# Epoch 87/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7602 - accuracy: 0.4729
# Epoch 88/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7593 - accuracy: 0.4733
# Epoch 89/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7584 - accuracy: 0.4739
# Epoch 90/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7575 - accuracy: 0.4746
# Epoch 91/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7566 - accuracy: 0.4762
# Epoch 92/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7557 - accuracy: 0.4775
# Epoch 93/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7548 - accuracy: 0.4781
# Epoch 94/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7539 - accuracy: 0.4787
# Epoch 95/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7530 - accuracy: 0.4796
# Epoch 96/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7522 - accuracy: 0.4805
# Epoch 97/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7513 - accuracy: 0.4816
# Epoch 98/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7504 - accuracy: 0.4832
# Epoch 99/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7495 - accuracy: 0.4839
# Epoch 100/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7487 - accuracy: 0.4850

# %%
ypred = ann.predict(xtest)
ypred = ypred > 0.5
ypred
# Out:
# 63/63 [==============================] - 0s 1ms/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.52      0.61      1585
#            1       0.15      0.31      0.20       415
#
#     accuracy                           0.48      2000
#    macro avg       0.44      0.42      0.41      2000
# weighted avg       0.62      0.48      0.53      2000

# %%
ann.evaluate(xtrain,ytrain)
# Out:
# 250/250 [==============================] - 1s 1ms/step - loss: 0.7483 - accuracy: 0.4851
# [0.7482582330703735, 0.48512500524520874]

# %% [markdown]
# # Hyperparameter tuning

# %%
list(range(8,128,8))
# Out:
# [8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120]

# %%
def hyper(hp): #This defines a function named hyper that takes a single argument hp.
    model = Sequential()
    counter = 0 #Initializes a counter variable to keep track of the current layer being added to the model.
    for i in range(hp.Int('num_layers', min_value = 1,max_value=10)):  #Loops through a range of layers, where the number of layers is a hyperparameter named 'num_layers' with a minimum value of 1 and a maximum value of 10.
        if counter ==0:
            model.add(Dense(hp.Int('units'+str(i),min_value=8,max_value=128,step=8),
                            activation = hp.Choice('activation'+str(i),values = ['relu','tanh','sigmoid']),
                            input_dim = 13))
            #Adds the first layer with input dimensions specified by input_dim=13.
            #The number of units ('units') and activation function ('activation') are hyperparameters,
            #and their values are determined by the hp object.
        else:
          model.add(Dense(
              hp.Int('units'+str(i),min_value=8,max_value=128,step=8),
              activation = hp.Choice('activation'+str(i),values = ['relu','tanh','sigmoid'])))
              #Adds subsequent layers (after the first layer) with hyperparameter-specified units and activation functions.

    counter+=1   #Increments the counter to keep track of the layers added.
    model.add(Dense(units = 1,activation='sigmoid'))   #Adds the output layer with a single unit and sigmoid activation function, typical for binary classification problems.
    model.compile(optimizer = hp.Choice('optimizer',values = ['adam','rmsprop','sgd']),
                loss = 'binary_crossentropy',metrics = 'accuracy')
    return model  #Returns the compiled model.

# %%
tuner = kf.RandomSearch(hyper,
                        objective = 'val_accuracy',
                        max_trials = 3)

# %%
tuner.search(xtrain,ytrain,epochs = 5, validation_data = (xtest,ytest))
# search() is similar to fit()
# Out:
# Trial 3 Complete [00h 00m 06s]
# val_accuracy: 0.7925000190734863
#
# Best val_accuracy So Far: 0.859499990940094
# Total elapsed time: 00h 00m 18s

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'num_layers': 4,
#  'units0': 72,
#  'activation0': 'relu',
#  'optimizer': 'adam',
#  'units1': 8,
#  'activation1': 'relu',
#  'units2': 8,
#  'activation2': 'relu',
#  'units3': 8,
#  'activation3': 'relu'}

# %%
tuned_model = tuner.get_best_models(num_models=1)[0]
# tuned_model.build(x.shape)

# %%
tuned_model.fit(xtrain,ytrain,epochs=50, validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 250/250 [==============================] - 3s 5ms/step - loss: 0.3413 - accuracy: 0.8606 - val_loss: 0.3349 - val_accuracy: 0.8565
# Epoch 2/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3379 - accuracy: 0.8618 - val_loss: 0.3348 - val_accuracy: 0.8595
# Epoch 3/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3355 - accuracy: 0.8650 - val_loss: 0.3347 - val_accuracy: 0.8615
# Epoch 4/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3326 - accuracy: 0.8645 - val_loss: 0.3360 - val_accuracy: 0.8565
# Epoch 5/50
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3307 - accuracy: 0.8652 - val_loss: 0.3376 - val_accuracy: 0.8620
# Epoch 6/50
# 250/250 [==============================] - 2s 6ms/step - loss: 0.3291 - accuracy: 0.8662 - val_loss: 0.3357 - val_accuracy: 0.8600
# Epoch 7/50
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3269 - accuracy: 0.8646 - val_loss: 0.3403 - val_accuracy: 0.8595
# Epoch 8/50
# 250/250 [==============================] - 2s 6ms/step - loss: 0.3261 - accuracy: 0.8683 - val_loss: 0.3355 - val_accuracy: 0.8595
# Epoch 9/50
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3253 - accuracy: 0.8675 - val_loss: 0.3374 - val_accuracy: 0.8565
# Epoch 10/50
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3243 - accuracy: 0.8661 - val_loss: 0.3387 - val_accuracy: 0.8565
# Epoch 11/50
# 250/250 [==============================] - 2s 8ms/step - loss: 0.3211 - accuracy: 0.8660 - val_loss: 0.3398 - val_accuracy: 0.8625
# Epoch 12/50
# 250/250 [==============================] - 2s 6ms/step - loss: 0.3197 - accuracy: 0.8699 - val_loss: 0.3409 - val_accuracy: 0.8565
# Epoch 13/50
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3191 - accuracy: 0.8675 - val_loss: 0.3399 - val_accuracy: 0.8615
# Epoch 14/50
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3176 - accuracy: 0.8704 - val_loss: 0.3418 - val_accuracy: 0.8545
# Epoch 15/50
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3159 - accuracy: 0.8724 - val_loss: 0.3438 - val_accuracy: 0.8550
# Epoch 16/50
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3151 - accuracy: 0.8690 - val_loss: 0.3396 - val_accuracy: 0.8570
# Epoch 17/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3130 - accuracy: 0.8717 - val_loss: 0.3416 - val_accuracy: 0.8590
# Epoch 18/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3117 - accuracy: 0.8729 - val_loss: 0.3472 - val_accuracy: 0.8560
# Epoch 19/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3105 - accuracy: 0.8729 - val_loss: 0.3444 - val_accuracy: 0.8550
# Epoch 20/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3092 - accuracy: 0.8749 - val_loss: 0.3493 - val_accuracy: 0.8520
# Epoch 21/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3081 - accuracy: 0.8731 - val_loss: 0.3436 - val_accuracy: 0.8520
# Epoch 22/50
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3068 - accuracy: 0.8739 - val_loss: 0.3474 - val_accuracy: 0.8510
# Epoch 23/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3060 - accuracy: 0.8766 - val_loss: 0.3422 - val_accuracy: 0.8560
# Epoch 24/50
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3049 - accuracy: 0.8764 - val_loss: 0.3478 - val_accuracy: 0.8515
# Epoch 25/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3029 - accuracy: 0.8770 - val_loss: 0.3462 - val_accuracy: 0.8595
# Epoch 26/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3020 - accuracy: 0.8760 - val_loss: 0.3487 - val_accuracy: 0.8540
# Epoch 27/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3018 - accuracy: 0.8779 - val_loss: 0.3501 - val_accuracy: 0.8555
# Epoch 28/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2985 - accuracy: 0.8792 - val_loss: 0.3503 - val_accuracy: 0.8530
# Epoch 29/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2991 - accuracy: 0.8785 - val_loss: 0.3478 - val_accuracy: 0.8525
# Epoch 30/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2989 - accuracy: 0.8761 - val_loss: 0.3468 - val_accuracy: 0.8595
# Epoch 31/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2966 - accuracy: 0.8796 - val_loss: 0.3503 - val_accuracy: 0.8595
# Epoch 32/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2945 - accuracy: 0.8829 - val_loss: 0.3535 - val_accuracy: 0.8525
# Epoch 33/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2948 - accuracy: 0.8844 - val_loss: 0.3490 - val_accuracy: 0.8595
# Epoch 34/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2942 - accuracy: 0.8831 - val_loss: 0.3507 - val_accuracy: 0.8560
# Epoch 35/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2933 - accuracy: 0.8829 - val_loss: 0.3546 - val_accuracy: 0.8535
# Epoch 36/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2919 - accuracy: 0.8815 - val_loss: 0.3589 - val_accuracy: 0.8565
# Epoch 37/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2908 - accuracy: 0.8836 - val_loss: 0.3513 - val_accuracy: 0.8555
# Epoch 38/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2903 - accuracy: 0.8838 - val_loss: 0.3514 - val_accuracy: 0.8520
# Epoch 39/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2897 - accuracy: 0.8831 - val_loss: 0.3562 - val_accuracy: 0.8505
# Epoch 40/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2893 - accuracy: 0.8830 - val_loss: 0.3534 - val_accuracy: 0.8565
# Epoch 41/50
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2888 - accuracy: 0.8835 - val_loss: 0.3574 - val_accuracy: 0.8515
# Epoch 42/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2874 - accuracy: 0.8864 - val_loss: 0.3574 - val_accuracy: 0.8505
# Epoch 43/50
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2874 - accuracy: 0.8832 - val_loss: 0.3577 - val_accuracy: 0.8510
# Epoch 44/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2842 - accuracy: 0.8879 - val_loss: 0.3573 - val_accuracy: 0.8535
# Epoch 45/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2861 - accuracy: 0.8836 - val_loss: 0.3597 - val_accuracy: 0.8555
# Epoch 46/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2834 - accuracy: 0.8867 - val_loss: 0.3657 - val_accuracy: 0.8455
# Epoch 47/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2832 - accuracy: 0.8871 - val_loss: 0.3649 - val_accuracy: 0.8470
# Epoch 48/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2833 - accuracy: 0.8871 - val_loss: 0.3651 - val_accuracy: 0.8490
# Epoch 49/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2829 - accuracy: 0.8869 - val_loss: 0.3591 - val_accuracy: 0.8485
# Epoch 50/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2813 - accuracy: 0.8865 - val_loss: 0.3620 - val_accuracy: 0.8525

# %%
tuned_model.evaluate(xtrain,ytrain)
# Out:
# 250/250 [==============================] - 0s 2ms/step - loss: 0.2698 - accuracy: 0.8947
# [0.2698045074939728, 0.8947499990463257]

# %%
tuned_model.evaluate(xtest,ytest)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8525
# [0.361998975276947, 0.8525000214576721]
